# %%
from sys import path

path.append('/media/disk2/packages')  # add user packages path to path
from echarts_imager import ECharts

option = {
    "title": {
        "text": "Basic Radar Chart"
    },
    "legend": {
        "data": ["Allocated Budget", "Actual Spending"]
    },
    "radar": {
        "indicator": [{
            "name": "Sales",
            "max": 6500
        }, {
            "name": "Administration",
            "max": 16000
        }, {
            "name": "Information Technology",
            "max": 30000
        }, {
            "name": "Customer Support",
            "max": 38000
        }, {
            "name": "Development",
            "max": 52000
        }, {
            "name": "Marketing",
            "max": 25000
        }]
    },
    "series": [{
        "name":
            "Budget vs spending",
        "type":
            "radar",
        "data": [{
            "value": [4200, 3000, 20000, 35000, 50000, 18000],
            "name": "Allocated Budget"
        }, {
            "value": [5000, 14000, 28000, 26000, 42000, 21000],
            "name": "Actual Spending"
        }]
    }]
}

ECharts(option, device_pixel_ratio=2)
# Out:
# [ECharts] The ticks may be not readable when set min: 0, max: 6500 and alignTicks: true
# [ECharts] The ticks may be not readable when set min: 0, max: 16000 and alignTicks: true
# [ECharts] The ticks may be not readable when set min: 0, max: 30000 and alignTicks: true
# [ECharts] The ticks may be not readable when set min: 0, max: 38000 and alignTicks: true
# [ECharts] The ticks may be not readable when set min: 0, max: 52000 and alignTicks: true
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2048x1536 at 0x7F5EBF44CB00>
